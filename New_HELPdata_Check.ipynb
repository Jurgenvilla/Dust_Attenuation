# %% [markdown]
# # Checking HELP new data after corrrection were applied with a larger sample from Buat et al., 2018

# %%
# Importing regular packages

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from astropy.table import Table
import pandas as pd
import os

# %matplotlib inline

# %%
# New HELP sample with corrected data for PACS

help_large   = Table.read('/home/jvilla/Documents/PhD_2018/3DHST_Data/COSMOS/\
COSMOS_HELP/COSMOS_20181106_corrected.fits', format = 'fits')

# %%
# The IDs, RA, DEC, photometry and redshift needed are saved in a new file called:
# 'HELP_subsample_merged.fits'

HELP_large = Table([help_large['help_id'], help_large['ra'], help_large['dec'],\
                        help_large['f_omegacam_u'], help_large['ferr_omegacam_u'], help_large['f_suprime_b'],\
                        help_large['ferr_suprime_b'], help_large['f_suprime_v'], help_large['ferr_suprime_v'],\
                        help_large['f_suprime_r'], help_large['ferr_suprime_r'], help_large['f_suprime_ip'],\
                        help_large['ferr_suprime_ip'], help_large['f_suprime_zpp'], help_large['ferr_suprime_zpp'],\
                        help_large['f_suprime_y'],help_large['ferr_suprime_y'], help_large['f_vista_j'],\
                        help_large['ferr_vista_j'], help_large['f_vista_h'], help_large['ferr_vista_h'],\
                        help_large['f_vista_ks'], help_large['ferr_vista_ks'], help_large['f_irac_i1'],\
                        help_large['ferr_irac_i1'],  help_large['f_irac_i2'],  help_large['ferr_irac_i2'],\
                        help_large['f_irac_i3'],  help_large['ferr_irac_i3'],  help_large['f_irac_i4'],\
                        help_large['ferr_irac_i4'],  help_large['f_mips_24'],  help_large['ferr_mips_24'],\
                        help_large['f_pacs_green'],  help_large['ferr_pacs_green'],  help_large['f_pacs_red'],\
                        help_large['ferr_pacs_red'], help_large['f_spire_250'], help_large['ferr_spire_250'],\
                        help_large['f_spire_350'], help_large['ferr_spire_350'], help_large['f_spire_500'],\
                        help_large['ferr_spire_500'], help_large['zspec']],\
               names = ('HELP_id', 'help_ra', 'help_dec',\
                        'help_f_omegacam_u', 'help_ferr_omegacam_u', 'help_f_suprime_b',\
                        'help_ferr_suprime_b', 'help_f_suprime_v', 'help_ferr_suprime_v',\
                        'help_f_suprime_r', 'help_ferr_suprime_r', 'help_f_suprime_ip',\
                        'help_ferr_suprime_ip', 'help_f_suprime_zp', 'help_ferr_suprime_zpp',\
                        'help_f_suprime_y', 'help_ferr_suprime_y', 'help_f_vista_j',\
                        'help_ferr_vista_j', 'help_f_vista_h', 'help_ferr_vista_h',\
                        'help_f_vista_ks', 'help_ferr_vista_ks', 'help_f_irac_i1',\
                        'help_ferr_irac_i1', 'help_f_irac_i2', 'help_ferr_irac_i2',\
                        'help_f_irac_i3', 'help_ferr_irac_i3', 'help_f_irac_i4',\
                        'help_ferr_irac_i4', 'help_f_mips_24', 'help_ferr_mips_24',\
                        'help_f_pacs_green', 'help_ferr_pacs_green', 'help_f_pacs_red',\
                        'help_ferr_pacs_red', 'help_f_spire_250', 'help_ferr_spire_250',\
                        'help_f_spire_350', 'help_ferr_spire_350', 'help_f_spire_500',\
                        'help_ferr_spire_500', 'help_zspec'))

os.system('rm -rf /home/jvilla/Documents/PhD_2018/3DHST_Data/COSMOS/HELP_SanityCheck/HELP_subsample_merged.fits')
HELP_large.write('/home/jvilla/Documents/PhD_2018/3DHST_Data/COSMOS/'
                 'HELP_SanityCheck/HELP_subsample_merged.fits', format='fits')

# %%
# The final smaller sample for HELP is loaded 
# New data from Buat et al.,2018 for 2774 objects

HELP_data = Table.read('/home/jvilla/Documents/PhD_2018/3DHST_Data/COSMOS/'
                       'HELP_SanityCheck/HELP_subsample_merged.fits', format = 'fits') 

herschel_buat_help = Table.read('/home/jvilla/Documents/PhD_2018/3DHST_Data/'
                                'COSMOS/HELP_Veronique_data/cosmos_sample_herschel-snr5.fits', format = 'fits')

# %%
HELP_bands = ['help_f_omegacam_u','help_ferr_omegacam_u','help_f_suprime_b',\
              'help_ferr_suprime_b','help_f_suprime_v','help_ferr_suprime_v',\
              'help_f_suprime_r','help_ferr_suprime_r','help_f_suprime_ip',\
              'help_ferr_suprime_ip','help_f_suprime_zp','help_ferr_suprime_zpp',\
              'help_f_suprime_y','help_ferr_suprime_y','help_f_vista_j',\
              'help_ferr_vista_j','help_f_vista_h','help_ferr_vista_h',\
              'help_f_vista_ks','help_ferr_vista_ks','help_f_irac_i1',\
              'help_ferr_irac_i1','help_f_irac_i2','help_ferr_irac_i2',\
              'help_f_irac_i3','help_ferr_irac_i3','help_f_irac_i4',\
              'help_ferr_irac_i4','help_f_mips_24','help_ferr_mips_24',\
              'help_f_pacs_green','help_ferr_pacs_green','help_f_pacs_red',\
              'help_ferr_pacs_red','help_f_spire_250','help_ferr_spire_250',\
              'help_f_spire_350','help_ferr_spire_350','help_f_spire_500','help_ferr_spire_500']

Buat_bands = ['CFHT_u','CFHT_u_err','subaru.suprime.B',\
              'subaru.suprime.B_err','subaru.suprime.V','subaru.suprime.V_err',\
              'subaru.suprime.r','subaru.suprime.r_err','subaru.suprime.i',\
              'subaru.suprime.i_err','subaru.suprime.z','subaru.suprime.z_err',\
              'subaru.hsc.y','subaru.hsc.y_err','ukirt.J',\
              'ukirt.J_err','cfht.wircam.H','cfht.wircam.H_err',\
              'vista.vircam.Ks','vista.vircam.Ks_err','spitzer.irac.ch1',\
              'spitzer.irac.ch1_err','spitzer.irac.ch2','spitzer.irac.ch2_err',\
              'spitzer.irac.ch3','spitzer.irac.ch3_err','spitzer.irac.ch4',\
              'spitzer.irac.ch4_err','spitzer.mips.24','spitzer.mips.24_err',\
              'herschel.pacs.100','herschel.pacs.100_err','herschel.pacs.160',\
              'herschel.pacs.160_err','herschel.spire.PSW','herschel.spire.PSW_err',\
              'herschel.spire.PMW','herschel.spire.PMW_err','herschel.spire.PLW','herschel.spire.PLW_err']

# %%
herschel_buat_help = herschel_buat_help.to_pandas()
herschel_buat_help = herschel_buat_help.fillna(-9999.99)
herschel_buat_help = Table.from_pandas(herschel_buat_help)

HELP_data          = HELP_data.to_pandas()
HELP_data          = HELP_data.fillna(-9999.99)
HELP_data          = Table.from_pandas(HELP_data)

# %%
print('Band: \t\t\t Data in Vero: \t\tNon_Zero:\tMy data:\tNon_zero:')
for i in range(len(HELP_bands)):
    
    x = herschel_buat_help[Buat_bands[i]][(herschel_buat_help[Buat_bands[i]] != -9999.99) &\
                                         (herschel_buat_help[Buat_bands[i]] < 5000)]
    y = HELP_data[HELP_bands[i]][(HELP_data[HELP_bands[i]] != -9999.99) &\
                                (HELP_data[HELP_bands[i]] < 5000)]
    
    print('%20s\t\t%i\t\t%i\t\t%i\t\t%i'\
          %(Buat_bands[i], len(herschel_buat_help[Buat_bands[i]]), len(x),\
            len(HELP_data[HELP_bands[i]]), len(y)))
# Out:
# Band: 			 Data in Vero: 		Non_Zero:	My data:	Non_zero:
#               CFHT_u		2774		2655		2599374		107267
#           CFHT_u_err		2774		2655		2599374		107274
#     subaru.suprime.B		2774		2744		2599374		678570
# subaru.suprime.B_err		2774		2744		2599374		678570
#     subaru.suprime.V		2774		2740		2599374		680681
# subaru.suprime.V_err		2774		2740		2599374		680681
#     subaru.suprime.r		2774		2765		2599374		2146162
# subaru.suprime.r_err		2774		2765		2599374		2143141
#     subaru.suprime.i		2774		2770		2599374		688862
# subaru.suprime.i_err		2774		2770		2599374		688862
#     subaru.suprime.z		2774		2760		2599374		689964
# subaru.suprime.z_err		2774		2760		2599374		689964
#         subaru.hsc.y		2774		2757		2599374		1961213
#     subaru.hsc.y_err		2774		2757		2599374		1960412
#              ukirt.J		2774		2312		2599374		527111
#          ukirt.J_err		2774		2312		2599374		527112
#        cfht.wircam.H		2774		2761		2599374		517440
#    cfht.wircam.H_err		2774		2761		2599374		517441
#      vista.vircam.Ks		2774		2313		2599374		512130
#  vista.vircam.Ks_err		2774		2313		2599374		512131
#     spitzer.irac.ch1		2774		2773		2599374		0
# spitzer.irac.ch1_err		2774		2773		2599374		0
#     spitzer.irac.ch2		2774		2773		2599374		0
# spitzer.irac.ch2_err		2774		2773		2599374		0
#     spitzer.irac.ch3		2774		2764		2599374		2
# spitzer.irac.ch3_err		2774		2764		2599374		2
#     spitzer.irac.ch4		2774		2770		2599374		10
# spitzer.irac.ch4_err		2774		2770		2599374		13
#      spitzer.mips.24		2774		2712		2599374		319110
#  spitzer.mips.24_err		2774		2712		2599374		319120
#    herschel.pacs.100		2774		1192		2599374		298676
# herschel.pacs.100_err		2774		1192		2599374		319295
#    herschel.pacs.160		2774		1192		2599374		235041
# herschel.pacs.160_err		2774		1192		2599374		273178
#   herschel.spire.PSW		2774		2176		2599374		10806
# herschel.spire.PSW_err		2774		2176		2599374		25513
#   herschel.spire.PMW		2774		2176		2599374		14919
# herschel.spire.PMW_err		2774		2176		2599374		25116
#   herschel.spire.PLW		2774		2176		2599374		19833
# herschel.spire.PLW_err		2774		2176		2599374		25279

# %%
test = Table.read('/home/jvilla/Documents/PhD_2018/3DHST_Data/'
                  'COSMOS/HELP_Veronique_data/Help_cosmos_sample_herschel-snr5.fits', format = 'fits')

# %%
test = test.to_pandas()
test = test.fillna(-9999.99)
test = Table.from_pandas(test)

# %%
print('Band: \t\t\t Data in Vero: \t\tNon_Zero:\tMy data:\tNon_zero:')
for i in range(len(HELP_bands)):
    
    x = test[Buat_bands[i]][(test[Buat_bands[i]] != -9999.99) & (test[Buat_bands[i]] < 5000)]
    y = test[HELP_bands[i]][(test[HELP_bands[i]] != -9999.99) & (test[HELP_bands[i]] < 5000)]
    
    print('%20s\t\t%i\t\t%i\t\t%i\t\t%i'\
          %(Buat_bands[i], len(test[Buat_bands[i]]), len(x),\
            len(test[HELP_bands[i]]), len(y)))
# Out:
# Band: 			 Data in Vero: 		Non_Zero:	My data:	Non_zero:
#               CFHT_u		2774		2655		2774		816
#           CFHT_u_err		2774		2655		2774		816
#     subaru.suprime.B		2774		2744		2774		2744
# subaru.suprime.B_err		2774		2744		2774		2744
#     subaru.suprime.V		2774		2740		2774		2740
# subaru.suprime.V_err		2774		2740		2774		2740
#     subaru.suprime.r		2774		2765		2774		2573
# subaru.suprime.r_err		2774		2765		2774		2570
#     subaru.suprime.i		2774		2770		2774		2770
# subaru.suprime.i_err		2774		2770		2774		2770
#     subaru.suprime.z		2774		2760		2774		2772
# subaru.suprime.z_err		2774		2760		2774		2772
#         subaru.hsc.y		2774		2757		2774		2763
#     subaru.hsc.y_err		2774		2757		2774		2763
#              ukirt.J		2774		2312		2774		2312
#          ukirt.J_err		2774		2312		2774		2312
#        cfht.wircam.H		2774		2761		2774		2314
#    cfht.wircam.H_err		2774		2761		2774		2314
#      vista.vircam.Ks		2774		2313		2774		2313
#  vista.vircam.Ks_err		2774		2313		2774		2313
#     spitzer.irac.ch1		2774		2773		2774		0
# spitzer.irac.ch1_err		2774		2773		2774		0
#     spitzer.irac.ch2		2774		2773		2774		0
# spitzer.irac.ch2_err		2774		2773		2774		0
#     spitzer.irac.ch3		2774		2764		2774		0
# spitzer.irac.ch3_err		2774		2764		2774		0
#     spitzer.irac.ch4		2774		2770		2774		0
# spitzer.irac.ch4_err		2774		2770		2774		0
#      spitzer.mips.24		2774		2712		2774		2758
#  spitzer.mips.24_err		2774		2712		2774		2759
#    herschel.pacs.100		2774		1192		2774		1309
# herschel.pacs.100_err		2774		1192		2774		2759
#    herschel.pacs.160		2774		1192		2774		882
# herschel.pacs.160_err		2774		1192		2774		1763
#   herschel.spire.PSW		2774		2176		2774		55
# herschel.spire.PSW_err		2774		2176		2774		2493
#   herschel.spire.PMW		2774		2176		2774		137
# herschel.spire.PMW_err		2774		2176		2774		2477
#   herschel.spire.PLW		2774		2176		2774		295
# herschel.spire.PLW_err		2774		2176		2774		2434

# %%
band_vero  = ['spitzer.mips.24',\
               'herschel.pacs.100', 'herschel.pacs.160',\
               'herschel.spire.PSW', 'herschel.spire.PMW', 'herschel.spire.PLW']

band_err_vero = ['spitzer.mips.24_err',\
                 'herschel.pacs.100_err', 'herschel.pacs.160_err',\
                 'herschel.spire.PSW_err', 'herschel.spire.PMW_err', 'herschel.spire.PLW_err']

band_mine = ['help_f_mips_24',\
             'help_f_pacs_green','help_f_pacs_red',\
             'help_f_spire_250', 'help_f_spire_350','help_f_spire_500']

band_err_mine = ['help_f_mips_24',\
                 'help_f_pacs_green','help_f_pacs_red',\
                 'help_f_spire_250', 'help_f_spire_350','help_f_spire_500']

# %%
X = np.linspace(0, 5000, 500)

fig, axs = plt.subplots(2,3, figsize=(18, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace = 0.45)

axs = axs.ravel()

for i in range(len(band_vero)):
    
    test = test[test[band_vero[i]] < 100]

    axs[i].scatter(test[band_vero[i]], test[band_mine[i]]*1e-3)
    axs[i].set_xlabel('Veronique [mJy]', fontsize = 15)
    axs[i].set_ylabel('Mine [mJy]', fontsize = 15)
    axs[i].plot(X, X, ls ='--', c = 'C1')
    axs[i].set_xlim(0, np.max(test[band_vero[i]]))
    axs[i].set_ylim(0, np.max(test[band_vero[i]]))
    axs[i].tick_params(axis = 'both', which = 'major', labelsize = 14)
    axs[i].legend(frameon = False, prop = {'size': 15}, markerscale = 3 , loc = 'upper left')
    axs[i].legend()
    
fig, axs = plt.subplots(2,3, figsize=(18, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace = 0.45)

axs = axs.ravel()

for i in range(len(band_vero)):

    x = test[band_err_vero[i]][test[band_err_vero[i]] != -9999.99]
    y = test[band_err_mine[i]][test[band_err_mine[i]] != -9999.99]
    
    x = x[(x > 0) & (x < 50)]
    y = y[(y*1e-3 > 0) & (y*1e-3 < 50)]
    
    axs[i].hist(x, histtype = 'step', label = 'Buat et al., 2018', bins = 'scott')
    axs[i].hist(y*1e-3, histtype = 'step', label = 'Mine', bins = 'scott')
#     axs[i].set_xlim(np.nanpercentile(y, 0.1), np.nanpercentile(y, 99.9))
    axs[i].set_xlabel('Uncertainty [mJy]', fontsize = 15)
    axs[i].set_ylabel('Number', fontsize = 15)
    axs[i].set_title('%s'%band_err_vero[i])
    axs[i].tick_params(axis = 'both', which = 'major', labelsize = 14)
    axs[i].legend(frameon = False, prop = {'size': 15}, markerscale = 3 , loc = 'upper left')
    axs[i].legend()
